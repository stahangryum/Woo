# %% [markdown]
# # XGBoost PPT
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Kim Jeewoo
# - categories: [JBIG]
# - image: images/kaggle_logo.png

# %% [markdown]
# # XGBoost(eXtra Gradient Boost)

# %% [markdown]
# # 목차
#
# ### Boosting Review
#
# ### XGBoost
#
# ##### - XGBoost 장점
#
# ##### - 주요 하이퍼파라미터
#
# ### LightGBM

# %% [markdown]
# # Boosting Review

# %% [markdown]
# ### Boosting
#
# - 여러 개의 약한 Decision Tree를 조합해서 사용하는 Ensemble 기법 중 하나이다.
#   - 즉, 약한 예측 모형들의 학습 에러에 가중치를 두고, 순차적으로 다음 학습 모델에 반영하여
#   -강한 예측모형을 만드는 것이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # XGBoost

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - XGBoost는 Extreme Gradient Boosting의 약자이다.
#
#
# - Boosting 기법을 이용하여 구현한 알고리즘은 Gradient Boost 가 대표적입니다.
#
#
# - 이 알고리즘을 병렬 학습이 지원되도록 구현한 라이브러리가 XGBoost 이다.
#
#
# - Regression, Classification 문제를 모두 지원하며, 성능과 자원 효율이 좋아서, 인기 있게 사용되는 알고리즘이다.

# %% [markdown]
# ### XGBoost의 장점

# %% [markdown]
# - GBM보다 빠르다!!!
#
# - 과적합 규제 기능을 제공한다!
#
# - Early Stopping(조기 종료) 기능이 있음
#
# - 하이퍼파라미터 튜닝에 용이!!!!!

# %% [markdown]
# ## 주요 하이퍼파라미터 - 사이킷런

# %% [markdown]
# |Parameter|설명|
# |--------|-------------|
# |mat_depth|트리 최대 깊이|
# |learning_rate|학습률|
# |objective|목적 함수|
# |n_estimators|결정트리의 개수|
# |early_stopping_rounds|조기 종료|

# %% [markdown]
# ### 조기 종료 설명
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # LightGBM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 기존의 XGBoost나 GBM은 트리의 깊이를 효과적으로 줄이기 위한 균형 트리 분할 (Level-Wise)을 사용합니다.
#
# - 최대한 균형 잡힌 트리를 유지하면서 분할하기 때문에 트리의 깊이가 최소화될 수 있습니다.
#
# - 이러한 균형 잡힌 트리를 생성하는 이유는 과적합을 방지할 수 있다 알려져 있기 때문입니다.
#
# - 그러나 균형을 맞추기 위한 시간이 오래 걸린다는 단점이 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - LightGBM의 리프 중심 분할 (Leaf-wise)은 트리의 균형을 맞추지 않고 최대 손실 값을 가지는 리프 노드를 지속적으로 분할하면서 트리의 깊이가 깊어지고 비대칭적인 트리가 생성됩니다.
#
# - 결과적으로 균형 트리 분할에 비해 손실값이 높은 노드에 대해 더 깊게 트리를 분할하며 손실값을 줄일 수 있기 때문에 다른 부스팅 계열 알고리즘보다 더 좋은 정확도나 비슷한 수준의 성능을 낼 수 있습니다.

# %% [markdown]
# # 파라미터 비교
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 수고하셨습니다.
